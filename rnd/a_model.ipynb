# %%
import tensorflow as tf
# Out:
# 2024-03-16 00:35:40.503898: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
input_shape = (512, 32, 1)


import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, BatchNormalization, LeakyReLU, Flatten, Dense
from tensorflow.keras.optimizers import Adam

# Define the sequential model
model = Sequential([
    # First Conv2D layer
    Conv2D(32, (3, 3), strides=(2, 2), padding='same', input_shape=(512, 32, 1)),
    BatchNormalization(),
    LeakyReLU(),

    # Second Conv2D layer
    Conv2D(64, (3, 3), strides=(2, 2), padding='same'),
    BatchNormalization(),
    LeakyReLU(),

    # Third Conv2D layer
    Conv2D(128, (3, 3), strides=(2, 2), padding='same'),
    BatchNormalization(),
    LeakyReLU(),

    # Fourth Conv2D layer
    Conv2D(256, (3, 3), strides=(2, 2), padding='same'),
    BatchNormalization(),
    LeakyReLU(),

    # Fifth Conv2D layer
    Conv2D(256, (3, 3), strides=(2, 2), padding='same'),
    BatchNormalization(),
    LeakyReLU(),

    # Sixth Conv2D layer
    Conv2D(256, (3, 3), strides=(2, 2), padding='same'),
    BatchNormalization(),
    LeakyReLU(),

    # Seventh Conv2D layer
    Conv2D(512, (3, 3), strides=(2, 2), padding='same'),
    BatchNormalization(),
    LeakyReLU(),

    # Flatten the output
    Flatten(),

    # Dense layer
    Dense(100, activation='relu'),
    Dense(1, activation='sigmoid')
])

# Model summary
model.summary()

# Compile the model
model.compile(
    optimizer=Adam(learning_rate=1e-05),
    loss="binary_crossentropy",
    metrics=["accuracy"],
)
# Out:
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_122 (Conv2D)         (None, 256, 16, 32)       320
#
#  batch_normalization_22 (Ba  (None, 256, 16, 32)       128
#  tchNormalization)
#
#  leaky_re_lu_14 (LeakyReLU)  (None, 256, 16, 32)       0
#
#  conv2d_123 (Conv2D)         (None, 128, 8, 64)        18496
#
#  batch_normalization_23 (Ba  (None, 128, 8, 64)        256
#  tchNormalization)
#
#  leaky_re_lu_15 (LeakyReLU)  (None, 128, 8, 64)        0
#
#  conv2d_124 (Conv2D)         (None, 64, 4, 128)        73856
#
#  batch_normalization_24 (Ba  (None, 64, 4, 128)        512
#  tchNormalization)
#
#  leaky_re_lu_16 (LeakyReLU)  (None, 64, 4, 128)        0
#
#  conv2d_125 (Conv2D)         (None, 32, 2, 256)        295168
#
#  batch_normalization_25 (Ba  (None, 32, 2, 256)        1024
#  tchNormalization)
#
#  leaky_re_lu_17 (LeakyReLU)  (None, 32, 2, 256)        0
#
#  conv2d_126 (Conv2D)         (None, 16, 1, 256)        590080
#
#  batch_normalization_26 (Ba  (None, 16, 1, 256)        1024
#  tchNormalization)
#
#  leaky_re_lu_18 (LeakyReLU)  (None, 16, 1, 256)        0
#
#  conv2d_127 (Conv2D)         (None, 8, 1, 256)         590080
#
#  batch_normalization_27 (Ba  (None, 8, 1, 256)         1024
#  tchNormalization)
#
#  leaky_re_lu_19 (LeakyReLU)  (None, 8, 1, 256)         0
#
#  conv2d_128 (Conv2D)         (None, 4, 1, 512)         1180160
#
#  batch_normalization_28 (Ba  (None, 4, 1, 512)         2048
#  tchNormalization)
#
#  leaky_re_lu_20 (LeakyReLU)  (None, 4, 1, 512)         0
#
#  flatten_15 (Flatten)        (None, 2048)              0
#
#  dense_53 (Dense)            (None, 100)               204900
#
#  dense_54 (Dense)            (None, 1)                 101
#
# =================================================================
# Total params: 2959177 (11.29 MB)
# Trainable params: 2956169 (11.28 MB)
# Non-trainable params: 3008 (11.75 KB)
# _________________________________________________________________
