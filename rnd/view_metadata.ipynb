# %%
import pandas as pd
PATH_TO_INPUT_DATA = "/cluster/datastore/simonmy/data/datav3"
# Out:
# /tmp/ipykernel_3085316/2337587516.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv(PATH_TO_INPUT_DATA + "/data_with_test.csv")
df
# Out:
#                               sqbundle_id  wav_duration_sec  \
# 0        32500921bfa969d37d0b36240f8e59d8         24.422369
# 1        340dd60b47d2e8d17d4ab6f7c81684f9         75.401442
# 2        340dd60b47d2e8d17d4ab6f7c81684f9         75.401442
# 3        340dd60b47d2e8d17d4ab6f7c81684f9         75.401442
# 4        399328d9efc94ec8cba799ffcaac4eec         36.592857
# ...                                   ...               ...
# 66915  98993c11c0e4e9cc0a222bc39e30b4.wav         10.000000
# 66916  1b4f2cfa2ef5b5d529bda3389f4c2a.wav         10.000000
# 66917  a068f56fe93b228b1c76107f706725.wav         10.000000
# 66918  5f3f62c6ccabc4ba6418c20c97d43a.wav         10.000023
# 66919  40e2bb48e0264f60e2b6bf61b78b7b.wav         10.000000
#
#        label_duration_sec  label_relative_start_sec  label_relative_end_sec  \
# 0               24.422369                  0.000000               24.422369
# 1               38.190698                  0.000000               38.190698
# 2               36.195621                 38.190698               74.386319
# 3                1.015123                 74.386319               75.401442
# 4               36.592857                  0.000000               36.592857
# ...                   ...                       ...                     ...
# 66915           10.000000                  0.000000               10.000000
# 66916           10.000000                  0.000000               10.000000
# 66917           10.000000                  0.000000               10.000000
# 66918           10.000023                  0.000000               10.000023
# 66919           10.000000                  0.000000               10.000000
#
#                      label                             file_name  \
# 0      electric_quad_drone  b38b70ca19ee224c3ba056f0de71de2b.wav
# 1      electric_quad_drone  213e5d27543966361c8b4475b4fc4cd0.wav
# 2      electric_quad_drone  213e5d27543966361c8b4475b4fc4cd0.wav
# 3      electric_quad_drone  213e5d27543966361c8b4475b4fc4cd0.wav
# 4      electric_quad_drone  befe19d94a8ffcdd09cc0beb0be092f0.wav
# ...                    ...                                   ...
# 66915     nature_chernobyl    98993c11c0e4e9cc0a222bc39e30b4.wav
# 66916     nature_chernobyl    1b4f2cfa2ef5b5d529bda3389f4c2a.wav
# 66917     nature_chernobyl    a068f56fe93b228b1c76107f706725.wav
# 66918     nature_chernobyl    5f3f62c6ccabc4ba6418c20c97d43a.wav
# 66919     nature_chernobyl    40e2bb48e0264f60e2b6bf61b78b7b.wav
#
#                           split
# 0      test_electric_quad_drone
# 1      test_electric_quad_drone
# 2      test_electric_quad_drone
# 3      test_electric_quad_drone
# 4      test_electric_quad_drone
# ...                         ...
# 66915                     train
# 66916                     train
# 66917                     train
# 66918                     train
# 66919                     train
#
# [66920 rows x 8 columns]
